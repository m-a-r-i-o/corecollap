# %% [markdown]
# # Star cluster simulation with core collapse
#
# The cluster starts as a [Plummer model](https://en.wikipedia.org/wiki/Plummer_model) which is spherically symmetric, with initially isotropic orbits and $N=10^5$ stars. The stars share the same mass $m$. The total mass is $M = Nm$. It was evolved up to $t=2 \times 10^4 t_d$ with $t_d=\sqrt{r_s^3/GM}$. The scale radius $r_s$ is a parameter of the model which is set to $1$. Moreover we set $G=M=1$. Hence $t_d=1$. As a consequence of these choices the initial scale density is also $\approx 1$, and so is the scale velocity.
#
# The file is a csv with ';' as a separator. The first columns is time (in units of $t_d$; every row is a measurement taken every $0.2$ $t_d$), the second is $\rho_c$, the central density within a fixed radius, the third is $\sigma_c$, the standard deviation of velocity within the same radius, the fourth is $r_\mathrm{half}$ i.e. the radius containing half the total number of particles, the fifth and last is $N_\mathrm{esc}$, the number of escapers. Escapers are stars that are unbound (energy > 0) and go far from the cluster, so they would essentially move in uniform rectilinear motion forever and would just be a burden to keep track of. They are removed from the star cluster.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.tsatools import detrend
from statsmodels.tsa.tsatools import add_lag
from ripser import ripser
from persim import plot_diagrams
from persim.landscapes import plot_landscape_simple

attractor_dimension = 5
np.random.seed(888)

# %%
cc = pd.read_csv('core_collapse_data.csv', sep = ';') #nbody.csv 
cc.head()
# Out:
#    time     rho_c   sigma_c    r_half  N_esc
# 0  0.01  0.324676  0.206907  1.273847      0
# 1  0.21  0.133690  0.198193  1.273847      0
# 2  0.41  0.229183  0.212280  1.273847      0
# 3  0.61  0.305577  0.265373  1.273847      0
# 4  0.81  0.343775  0.276828  1.273847      0

# %%
cc.describe()
# Out:
#                 time          rho_c        sigma_c         r_half  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     9999.910000      43.678593       0.322060       2.580439
# std      5773.531559      34.429813       0.050671       1.248470
# min         0.010000       0.076394       0.079117       1.208252
# 25%      4999.960000       3.031902       0.289725       1.318540
# 50%      9999.910000      60.943611       0.331004       2.299209
# 75%     14999.860000      77.120119       0.364744       3.719175
# max     19999.810000      89.897078       0.399282       4.941489
#
#                N_esc
# count  100000.000000
# mean     7320.760210
# std      4511.474699
# min         0.000000
# 25%      2986.000000
# 50%      7795.000000
# 75%     11583.000000
# max     13846.000000

# %% [markdown]
# ### Central density as a function of time
# Let's plot the central density (mass per unit volume) within a fixed radius around the center of mass of the cluster.

# %%
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(cc['time'], cc['rho_c'], color = '#AC1208')
plt.xlabel('t')
plt.ylabel('Central density')
plt.show()

# %% [markdown]
# The density starts at $\approx 1$ ($0.32$ in fact) but climbs up to $\approx 80$, to decrease later on. The moment the maximum density is attained is the core-collapse.
# Let's zoom in to see this better.

# %%
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(cc['time'], cc['rho_c'], color = '#AC1208')
plt.xlabel('t')
plt.ylabel('Central density')
plt.xlim([11000, 16000])
plt.show()

# %% [markdown]
# Some more...

# %%
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(cc['time'], cc['rho_c'], color = '#AC1208')
plt.xlabel('t')
plt.ylabel('Central density')
plt.xlim([12000, 13000])
plt.show()

# %% [markdown]
# Let's look at the time evolution of the central velocity dispersion, over the whole evolution at first

# %%
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(cc['time'], cc['sigma_c'], color = '#3C12B8')
plt.xlabel('t')
plt.ylabel('Central velocity dispersion')
plt.show()

# %% [markdown]
# Then let's restrict the plot to the same time window around the core collapse

# %%
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(cc['time'], cc['sigma_c'], color = '#3C12B8')
plt.xlabel('t')
plt.ylabel('Central velocity dispersion')
plt.xlim([12000, 13000])
plt.show()

# %% [markdown]
# Both the density and the velocity dispersion appear roughly constant, with some variation that looks like noise. It is really noise (the sum of many different uncorrelated effects) or is it fluctuations that arise from some underlying (low dimensional) dynamics? Hopefully we will find out.
#
# Let's smooth by calculating a running mean over 10 dynamical times (50 time steps) and plot one against the other

# %%
smooth_over_N = 50
running_mean_sigma = np.convolve(cc['sigma_c'], np.ones(smooth_over_N)/smooth_over_N, mode='valid')
running_mean_rho = np.convolve(cc['rho_c'], np.ones(smooth_over_N)/smooth_over_N, mode='valid')
plt.figure(figsize=(9, 9), dpi=300)
plt.plot(running_mean_rho, running_mean_sigma, color = '#A298A0')
plt.xlabel('Central density')
plt.ylabel('Central velocity dispersion')
plt.xlim([84.0, 87.0]) #change these to explore
plt.ylim([0.37, 0.39])
plt.show()

# %% [markdown]
# This definitely looks cool. But smoothing noise can produce all kinds of apparent structure, so we might be deceiving ourselves.
#
# Example:

# %%
x = np.convolve(np.random.normal(size=2000), np.ones(1000)/1000, mode='valid')
y = np.convolve(np.random.normal(size=2000), np.ones(1000)/1000, mode='valid')

plt.plot(x,y, color = "#989998")
plt.show()

# %% [markdown]
# We can go back to the raw data and take a look at how much autocorrelation there is. We can plot our time series against itself, lagged by some amount, using pandas lag_plot. Or we can calculate the autocorrelation using plot_acf from statsmodels.

# %%
rho_c_around_cc = cc['rho_c'][cc['time'] > 15000] #we care about post-collapse evolution

plt.plot(np.arange(len(rho_c_around_cc)), rho_c_around_cc)
plt.show()

# %% [markdown]
# We should detrend the time series before calculating the ACF

# %%
detrended_rho_c_around_cc = detrend(rho_c_around_cc, order=3, axis=0)

# %%
plt.plot(np.arange(len(detrended_rho_c_around_cc)), detrended_rho_c_around_cc)
plt.show()

# %%
_ = plot_acf(detrended_rho_c_around_cc, lags = 1000, use_vlines=False, zero=False, auto_ylims=True)

# %% [markdown]
# It looks like the fist lag at which the autocorrelation loses significance is about 500. According to [Ravishanker & Chen 2021](https://wires.onlinelibrary.wiley.com/doi/full/10.1002/wics.1548?casa_token=NjV3TVkgfG4AAAAA%3AWgKxwvpeNn3xHMbwiJl0D0Tz4Cfj5RZjNUtE-3GrvCxEE664HJ0wC1TjyRkxKdGwEz-a803AK_xQee7p) we should choose $\tau \approx 500$ to build our Takens embedding. As for the dimension $d$ we suspect it to be around two or three. Let's choose $5$ to splurge.

# %%
selected = np.array([int(x) for x in range(len(detrended_rho_c_around_cc)) if x%500==0])

subsampled_detrended_rho_c_around_cc = detrended_rho_c_around_cc.to_numpy()[selected]

Nlags = add_lag(subsampled_detrended_rho_c_around_cc, lags=attractor_dimension)

# %% [markdown]
# Next step is to compute a persistence diagram on this data (the presumed attractor). We will then compute a persistence diagram on the velocity dispersion (following a similar detrending and subsampling procedure). If the topology of the two data sets is similar, as it should be if by takens theorem they are embedding the same attractor, then we can confirm that core oscillations live near a low-dimensional attractor. We will then also repeat this analysis on MPCDSS data (instead of direct N-body data) and compare the persistence diagrams across the two.
# This is another measure of realism...

# %%
diagrams = ripser(Nlags, maxdim=2)['dgms']
plot_diagrams(diagrams, show=True)

# %% [markdown]
# Let's redo everything with the central velocity dispersion sigma

# %%
sigma_c_around_cc = cc['sigma_c'][cc['time'] > 15000] #we care about post-collapse evolution
plt.plot(np.arange(len(sigma_c_around_cc)), sigma_c_around_cc)
plt.show()

# %%
detrended_sigma_c_around_cc = detrend(sigma_c_around_cc, order=3, axis=0)
plt.plot(np.arange(len(detrended_sigma_c_around_cc)), detrended_sigma_c_around_cc)
plt.show()

# %%
_ = plot_acf(detrended_sigma_c_around_cc, lags = 1000, use_vlines=False, zero=False, auto_ylims=True)

# %% [markdown]
# Similar lag (about 500) for which the autocorrelation becomes insignificant. Good!

# %%
subsampled_detrended_sigma_c_around_cc = detrended_sigma_c_around_cc.to_numpy()[selected]

Nlags_sigma = add_lag(subsampled_detrended_sigma_c_around_cc, lags=attractor_dimension)

# %%
diagrams_sigma = ripser(Nlags_sigma, maxdim=2)['dgms']
plot_diagrams(diagrams_sigma, show=True)

# %% [markdown]
# It looks pretty similar. The problem is that it also look like noise...
#
# What if we put them together?

# %%
Nlags_together = np.concatenate([Nlags, Nlags_sigma], 1)

diagrams_together = ripser(Nlags_together, maxdim=2)['dgms']
plot_diagrams(diagrams_together, show=True)

# %% [markdown]
# Noise alone, noise together...

# %% [markdown]
# ### Maybe better luck with the N-body?

# %%
cc_nbd = pd.read_csv('nbody.csv', sep = ',') #
cc_nbd.head()
# Out:
#       t   sigma_c     rho_c        rh        rc
# 0  0.01  0.143239  0.209954  1.277587  0.063025
# 1  1.01  0.286479  0.293832  1.277587  0.075788
# 2  2.01  0.286479  0.245069  1.277587  0.082713
# 3  3.01  0.310352  0.174619  1.277587  0.071101
# 4  4.01  0.286479  0.229190  1.277587  0.068817

# %%
plt.plot(cc_nbd['t'], cc_nbd['sigma_c'], color = "#24813A")
plt.show()

sigma_c_around_cc_nbd = cc_nbd['sigma_c'][np.abs(cc_nbd['t'] - 6000) < 1500] #we care about post-collapse evolution
plt.plot(np.arange(len(sigma_c_around_cc_nbd)), sigma_c_around_cc_nbd, color = "#24813A")
plt.show()

# %%
detrended_sigma_c_around_cc_nbd = detrend(sigma_c_around_cc_nbd, order=3, axis=0)
plt.plot(np.arange(len(detrended_sigma_c_around_cc_nbd)), detrended_sigma_c_around_cc_nbd, color = "#24813A")
plt.show()

# %%
_ = plot_acf(detrended_sigma_c_around_cc_nbd, lags = 100, use_vlines=False, zero=False, auto_ylims=True, color = "#24813A")

# %% [markdown]
# Now the lag at which the ACF loses significance seems about 30

# %%
selected_nbd = np.array([int(x) for x in range(len(detrended_sigma_c_around_cc_nbd)) if x%30==0])

subsampled_detrended_sigma_c_around_cc_nbd = detrended_sigma_c_around_cc_nbd.to_numpy()[selected_nbd]

N = 5
Nlags_sigma_nbd = add_lag(subsampled_detrended_sigma_c_around_cc_nbd, lags=attractor_dimension)
diagrams_sigma_nbd = ripser(Nlags_sigma_nbd, maxdim=2)['dgms']
plot_diagrams(diagrams_sigma_nbd, show=True)

# %% [markdown]
# Noise! Once again!
#
# #### Now let's take a look at core density

# %%
plt.plot(cc_nbd['t'], cc_nbd['rho_c'], color = "#E5E001")
plt.show()

rho_c_around_cc_nbd = cc_nbd['rho_c'][np.abs(cc_nbd['t'] - 6000) < 1500] #we care about post-collapse evolution
plt.plot(np.arange(len(rho_c_around_cc_nbd)), rho_c_around_cc_nbd, color = "#E5E001")
plt.show()

# %%
detrended_rho_c_around_cc_nbd = detrend(rho_c_around_cc_nbd, order=3, axis=0)
plt.plot(np.arange(len(detrended_rho_c_around_cc_nbd)), detrended_rho_c_around_cc_nbd, color = "#E5E001")
plt.show()

# %%
_ = plot_acf(detrended_rho_c_around_cc_nbd, lags = 100, use_vlines=False, zero=False, auto_ylims=True, color = "#E5E001")

# %%
subsampled_detrended_rho_c_around_cc_nbd = detrended_rho_c_around_cc_nbd.to_numpy()[selected_nbd]

Nlags_rho_nbd = add_lag(subsampled_detrended_rho_c_around_cc_nbd, lags=attractor_dimension)
diagrams_rho_nbd = ripser(Nlags_rho_nbd, maxdim=2)['dgms']
plot_diagrams(diagrams_rho_nbd, show=True)

# %% [markdown]
# Still it looks like noise!

# %% [markdown]
# ### Now let's compute bottleneck distances between diagrams

# %%
from persim import bottleneck

#distance between the rho and sigma diagram, both nbody
distance_bottleneck_rho_vs_sigma_nbd, matching = bottleneck(diagrams_rho_nbd[1], diagrams_sigma_nbd[1], matching=True)
#distance between the rho and the rho nbody diagram
distance_bottleneck_rho_vs_rho_nbd, matching = bottleneck(diagrams_rho_nbd[1], diagrams[1], matching=True)
#distance between the rho and sigma diagram, both MPCDSS
distance_bottleneck_rho_vs_sigma, matching = bottleneck(diagrams[1], diagrams_sigma[1], matching=True)
#distance between the sigma and the sigma nbody diagram
distance_bottleneck_sigma_vs_sigma_nbd, matching = bottleneck(diagrams_sigma_nbd[1], diagrams_sigma[1], matching=True)


print(distance_bottleneck_rho_vs_sigma_nbd)
print(distance_bottleneck_rho_vs_rho_nbd)
print(distance_bottleneck_rho_vs_sigma)
print(distance_bottleneck_sigma_vs_sigma_nbd)
# Out:
# 0.07056763768196106
# 0.19306141138076782
# 0.19306141138076782
# 0.07056763768196106

# %% [markdown]
# What did we learn from this?
#
# ### what would happen with a periodic signal?

# %%
length_of_artificial_signal = 3000
artificial_sine = 15*np.sin(0.05*np.arange(3000))+0.00001*np.arange(3000)*np.arange(3000) + 15*np.random.normal(size=3000)
plt.plot(np.arange(len(artificial_sine)), artificial_sine, color = "#739122")
plt.show()
detrended_artificial_sine = detrend(artificial_sine, order=3, axis=0)
plt.plot(np.arange(len(detrended_artificial_sine)), detrended_artificial_sine, color = "#739122")
plt.show()
_ = plot_acf(detrended_artificial_sine, lags = 1000, use_vlines=False, zero=False, auto_ylims=True, color = "#739122")
plt.show()
selected_art = np.array([int(x) for x in range(len(detrended_artificial_sine)) if x%30==0])
subsampled_detrended_artificial_sine = detrended_artificial_sine[selected_art]

Nlags_artif = add_lag(subsampled_detrended_artificial_sine, lags=attractor_dimension)
diagrams_artif = ripser(Nlags_artif, maxdim=2)['dgms']
plot_diagrams(diagrams_artif, show=True)

# %% [markdown]
# ### and with a random signal (iid, normal)?

# %%
length_of_artificial_signal = 3000
artificial_sine = np.random.normal(size=3000)
plt.plot(np.arange(len(artificial_sine)), artificial_sine, color = "#739122")
plt.show()
detrended_artificial_sine = detrend(artificial_sine, order=3, axis=0)
plt.plot(np.arange(len(detrended_artificial_sine)), detrended_artificial_sine, color = "#739122")
plt.show()
_ = plot_acf(detrended_artificial_sine, lags = 1000, use_vlines=False, zero=False, auto_ylims=True, color = "#739122")
plt.show()
selected_art = np.array([int(x) for x in range(len(detrended_artificial_sine)) if x%30==0])
subsampled_detrended_artificial_sine = detrended_artificial_sine[selected_art]

Nlags_artif = add_lag(subsampled_detrended_artificial_sine, lags=attractor_dimension)
diagrams_artif = ripser(Nlags_artif, maxdim=2)['dgms']
plot_diagrams(diagrams_artif, show=True)

# %% [markdown]
# ### how about a Brownian motion?

# %%
np.random.seed(882)
length_of_artificial_signal = len(rho_c_around_cc)
artificial_sine = np.random.normal(size=3000).cumsum()
plt.plot(np.arange(len(artificial_sine)), artificial_sine, color = "#739122")
plt.show()
detrended_artificial_sine = detrend(artificial_sine, order=3, axis=0)
plt.plot(np.arange(len(detrended_artificial_sine)), detrended_artificial_sine, color = "#739122")
plt.show()
_ = plot_acf(detrended_artificial_sine, lags = 1000, use_vlines=False, zero=False, auto_ylims=True, color = "#739122")
plt.show()
selected_art = np.array([int(x) for x in range(len(detrended_artificial_sine)) if x%150==0])
subsampled_detrended_artificial_sine = detrended_artificial_sine[selected_art]

Nlags_artif = add_lag(subsampled_detrended_artificial_sine, lags=attractor_dimension)
diagrams_artif = ripser(Nlags_artif, maxdim=2)['dgms']
plot_diagrams(diagrams_artif, show=True)

# %%
dgms = ripser(Nlags_together, maxdim=2)['dgms']

plot_diagrams(dgms)
plt.show()
diagrams_artif = ripser(Nlags_artif, maxdim=2)['dgms']
plot_diagrams(diagrams_artif)
plt.show()

# %% [markdown]
# ### let's try with the rossler attractor

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def rossler_eq(y, t, a, b, c):
    x, y, z = y
    dxdt = -y - z
    dydt = x + a*y
    dzdt = b + z*(x - c)
    return [dxdt, dydt, dzdt]

a = 0.2
b = 0.2
c = 5.7
y0 = [1, 1, 1]
t = np.linspace(0, 100, len(rho_c_around_cc))

sol = odeint(rossler_eq, y0, t, args=(a, b, c))

x = sol[:, 0]
y = sol[:, 1]
z = sol[:, 2]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(z, y, x)
plt.show()

len(x)
# Out:
# 25000

# %%
rossler = y
plt.plot(np.arange(len(rossler)), rossler, color = "#FA8072")
plt.show()
detrended_rossler = detrend(rossler, order=3, axis=0)
plt.plot(np.arange(len(detrended_rossler)), detrended_rossler, color = "#FA8072")
plt.show()
_ = plot_acf(detrended_rossler, lags = 2000, use_vlines=False, zero=False, auto_ylims=True, color = "#FA8072")
plt.show()
selected_ross = np.array([int(x) for x in range(len(detrended_rossler)) if x%1000==0])
subsampled_detrended_rossler = detrended_rossler[selected_ross]

Nlags_ross = add_lag(subsampled_detrended_rossler, lags=attractor_dimension)
dgms_ross = ripser(Nlags_ross, maxdim=2)['dgms']
plot_diagrams(dgms_ross, title="Rossler's attractor")
plt.show()

plot_diagrams(diagrams_artif, title="Brownian motion")
plt.show()

# %% [markdown]
# ### Let's compare the persistent entropy of the diagrams between brownian motion and Rossler

# %%
from persim.persistent_entropy import *

# %%
pe_ross = persistent_entropy(dgms_ross)
pe_ross
# Out:
# array([ 2.87529662,  1.17788762, -0.        ])

# %%
length_of_artificial_signal = len(rossler)

pe_0 = []
pe_1 = []
pe_2 = []
for i in range(1000):
    brownian = np.random.normal(size=length_of_artificial_signal).cumsum()
    detrended_brownian = detrend(brownian, order=3, axis=0)
    selected_brown = np.array([int(x) for x in range(len(detrended_brownian)) if x%150==0])
    subsampled_detrended_brownian = detrended_brownian[selected_art]
    Nlags_brown = add_lag(subsampled_detrended_brownian, lags=attractor_dimension)
    diagrams_brown = ripser(Nlags_brown, maxdim=2)['dgms']
    pe = persistent_entropy(diagrams_brown)
    pe_0.append(pe[0])
    pe_1.append(pe[1])
    pe_2.append(pe[2])
    
plt.hist(pe_0)
plt.vlines(pe_ross[0], 0, 350, color = "#C49502")
plt.show()
plt.hist(pe_1)
plt.vlines(pe_ross[1], 0, 160, color = "#C49502")
plt.show()
plt.hist(pe_2)
plt.vlines(pe_ross[2], 0, 800, color = "#C49502")
plt.show()

# %% [markdown]
# ### Now the same with central density in MPCDSS data

# %%
pe_dens = persistent_entropy(diagrams)
pe_dens

plt.hist(pe_0)
plt.vlines(pe_dens[0], 0, 350, color = "#C49502")
plt.show()
plt.hist(pe_1)
plt.vlines(pe_dens[1], 0, 160, color = "#C49502")
plt.show()
plt.hist(pe_2)
plt.vlines(pe_dens[2], 0, 800, color = "#C49502")
plt.show()

# %%
len(rho_c_around_cc)
# Out:
# 25000

# %%
len(rho_c_around_cc_nbd)
# Out:
# 3000
